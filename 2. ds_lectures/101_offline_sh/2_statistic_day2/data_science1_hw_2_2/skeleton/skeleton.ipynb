# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/data.csv')

# "normal_outliers" 열만 추출해 Series로 만듦
normal_outliers = pd.Series(df['normal_outliers'])
# "pareto_outliers" 열만 추출해 Series로 만듦 (pareto 분포는 긴꼬리 분포의 일종)
pareto_outliers = pd.Series(df['pareto_outliers'])


# 시각화
plt.figure(figsize=(8, 5))
sns.histplot(normal_outliers, bins=30, kde=True, color='blue', label='Normal with Outliers')
sns.histplot(pareto_outliers, bins=30, kde=True, color='red', label='Pareto with Outliers', alpha=0.6)
plt.title('Normal distribution with outliers vs Pareto distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# %%
print("normal_outliers의 평균과 분산")
print(f"평균: {np.mean(normal_outliers):.2f}")
print(f"분산: {np.var(normal_outliers):.2f}")
print()
print("pareto_outliers 평균과 분산")
print(f"평균: {np.mean(pareto_outliers):.2f}")
print(f"분산: {np.var(pareto_outliers):.2f}")

# 이상치를 포함하고 있는 pereto의 분산을 확인했을 때 매우 크게 나왔음을 확인할 수 있음
# Out:
# normal_outliers의 평균과 분산
# 평균: 50.79
# 분산: 219.54
#
# pareto_outliers 평균과 분산
# 평균: 46.16
# 분산: 952.45
