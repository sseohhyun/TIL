# %%
import mlflow

mlflow.set_tracking_uri("http://localhost:5000") # MLflow Tracking 서버 URI 설정
mlflow.set_experiment("my_first_experiment") # 원하는 실험명을 작성
# Out:
# 2025/10/01 14:26:36 INFO mlflow.tracking.fluent: Experiment with name 'my_first_experiment' does not exist. Creating a new experiment.
# <Experiment: artifact_location='file:///C:/Users/SSAFY/mlflow_project/mlruns/1', creation_time=1759296396659, experiment_id='1', last_update_time=1759296396659, lifecycle_stage='active', name='my_first_experiment', tags={}>

# %%
accuracy = [0.85, 0.88, 1.0, 0.9, 0.85]

for i in range(5): 
    with mlflow.start_run():
        mlflow.log_params({"pram1": i + 1})
        mlflow.log_metric("accuracy", accuracy[i])
# Out:
# 🏃 View run abundant-fowl-352 at: http://localhost:5000/#/experiments/1/runs/5efd3fb4d0434cf7ac027d9389466950
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 🏃 View run thoughtful-trout-875 at: http://localhost:5000/#/experiments/1/runs/e5a7516c538c4e42b87a374d28100663
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 🏃 View run sneaky-mule-366 at: http://localhost:5000/#/experiments/1/runs/aac7ed204f374e4b87e431be11a34e6c
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 🏃 View run traveling-carp-874 at: http://localhost:5000/#/experiments/1/runs/8b55a1aae76b439a8cc96514384b1fcc
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 🏃 View run lyrical-gnat-44 at: http://localhost:5000/#/experiments/1/runs/c8f43eb5e8474b098dcec938f958bb1a
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %% [markdown]
# ![image.png](attachment:image.png)
